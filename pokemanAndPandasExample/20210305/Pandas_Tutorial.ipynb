# %% [markdown]
# ## PTR Coding Circle 20210305: Pandas
# -see README.md on making a virtual environment to explore pandas

# %% [markdown]
# # Background
# Last time we learned about different types of data structures:
# -lists
# -dictionaries
# -tuples
# -sets

# %%
# examples
list1 = ['I', 'am', 'a', 'list']
print(list1[-1])
dict1 = {'20210115' : 'Importing images', '20210305': "Introduction to Pandas"}
print(dict1['20210305'])
# Out:
# list
# Introduction to Pandas

# %% [markdown]
# #### Note
# -square brackets [ ] are used to designate a location
# -this is a common python syntax

# %% [markdown]
# ## Data structure
# It is important to match the data strcucture to need.
# As data scientists we often work with tabulated data:
#     row and columns.
# Tabulated data cannot be easily parsed into dictionaries or lists!!!
# What to do?
#    Pandas to the rescue
#
# Pandas fills all four steps when analyzing data:
# 1. Import data
# 2. Clean data
# 3. Process data
# 4. Export data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Importing data
# Pandas can import many types of tabulted data:
# -excel files
# -csv files
# -text files

# %%
poke_xls = pd.read_excel('pokemon_data.xlsx', index_col = 0) #index_col tell read_excel to use the first column as the index
poke_xls
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1                Bulbasaur    Grass  Poison  45      49       49       65
# 2                  Ivysaur    Grass  Poison  60      62       63       80
# 3                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 719                Diancie     Rock   Fairy  50     100      150      100
# 719    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 720    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 720     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 721              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
poke_csv = pd.read_csv('pokemon_data.csv', index_col=0)
poke_csv
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1                Bulbasaur    Grass  Poison  45      49       49       65
# 2                  Ivysaur    Grass  Poison  60      62       63       80
# 3                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 719                Diancie     Rock   Fairy  50     100      150      100
# 719    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 720    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 720     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 721              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# #
# ...

# %% [markdown]
# #2. Checking and cleaning data
# a. what is in the data
# b. what data does not belong

# %%
poke_csv.dtypes
# Out:
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
poke_csv.describe()
# Out:
#                HP      Attack     Defense     Sp. Atk     Sp. Def       Speed  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean    69.258750   79.001250   73.842500   72.820000   71.902500   68.277500
# std     25.534669   32.457366   31.183501   32.722294   27.828916   29.060474
# min      1.000000    5.000000    5.000000   10.000000   20.000000    5.000000
# 25%     50.000000   55.000000   50.000000   49.750000   50.000000   45.000000
# 50%     65.000000   75.000000   70.000000   65.000000   70.000000   65.000000
# 75%     80.000000  100.000000   90.000000   95.000000   90.000000   90.000000
# max    255.000000  190.000000  230.000000  194.000000  230.000000  180.000000
#
#        Generation
# count   800.00000
# mean      3.32375
# std       1.66129
# min       1.00000
# 25%       2.00000
# 50%       3.00000
# 75%       5.00000
# max       6.00000

# %%
poke_csv.shape
# Out:
# (800, 11)

# %% [markdown]
# # How to select columns, rows and single cells?

# %%
#selecting a column
print(poke_csv['HP']) # best method
print(poke_csv.HP) #showing an alternative but DO NOT USE
# Out:
# #
# 1      45
# 2      60
# 3      80
# 3      80
# 4      39
#        ..
# 719    50
# 719    50
# 720    80
# 720    80
# 721    80
# Name: HP, Length: 800, dtype: int64
# #
# 1      45
# 2      60
# 3      80
# 3      80
# 4      39
#        ..
# 719    50
# 719    50
# 720    80
# 720    80
# 721    80
# Name: HP, Length: 800, dtype: int64

# %%
poke_csv.index[0]
# Out:
# 1

# %%
#selecting a single row
print(poke_csv.loc['1']) # selecting by the index
print(poke_csv.iloc[0]) #selecting by row number---remember python starts the count at 0
# Out:
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 1, dtype: object
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 1, dtype: object

# %%
#selecting a single cell
print(poke_csv['HP'].loc[1])
print(poke_csv.loc[1, 'HP'])
# Out:
# 45
# 45

# %%
#this data is too clean, replace a value with Not a number (NaN)
poke_csv.loc[1, 'HP'] = np.NaN

# %%
#selecting a single cell
print(poke_csv['HP'].loc[1])
print(poke_csv.loc[1, 'HP'])
# Out:
# nan
# nan

# %%
poke_csv.describe()
# Out:
#                HP      Attack     Defense     Sp. Atk     Sp. Def       Speed  \
# count  799.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean    69.289111   79.001250   73.842500   72.820000   71.902500   68.277500
# std     25.536210   32.457366   31.183501   32.722294   27.828916   29.060474
# min      1.000000    5.000000    5.000000   10.000000   20.000000    5.000000
# 25%     50.000000   55.000000   50.000000   49.750000   50.000000   45.000000
# 50%     65.000000   75.000000   70.000000   65.000000   70.000000   65.000000
# 75%     80.000000  100.000000   90.000000   95.000000   90.000000   90.000000
# max    255.000000  190.000000  230.000000  194.000000  230.000000  180.000000
#
#        Generation
# count   800.00000
# mean      3.32375
# std       1.66129
# min       1.00000
# 25%       2.00000
# 50%       3.00000
# 75%       5.00000
# max       6.00000

# %% [markdown]
# # 2. Cleaning up the data
# I usaually spend >50% time in this section but not for this example.

# %%
poke_csv
# Out:
#                       Name   Type 1  Type 2    HP  Attack  Defense  Sp. Atk  \
# #
# 1                Bulbasaur    Grass  Poison   NaN      49       49       65
# 2                  Ivysaur    Grass  Poison  60.0      62       63       80
# 3                 Venusaur    Grass  Poison  80.0      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80.0     100      123      122
# 4               Charmander     Fire     NaN  39.0      52       43       60
# ..                     ...      ...     ...   ...     ...      ...      ...
# 719                Diancie     Rock   Fairy  50.0     100      150      100
# 719    DiancieMega Diancie     Rock   Fairy  50.0     160      110      160
# 720    HoopaHoopa Confined  Psychic   Ghost  80.0     110       60      150
# 720     HoopaHoopa Unbound  Psychic    Dark  80.0     160       60      170
# 721              Volcanion     Fire   Water  80.0     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
#remove rows with NaN
poke_csv.dropna(axis=0, how='any', inplace=True)

# %%
poke_csv.set_index(['Name'])
# Out:
#                             Type 1  Type 2    HP  Attack  Defense  Sp. Atk  \
# Name
# Ivysaur                      Grass  Poison  60.0      62       63       80
# Venusaur                     Grass  Poison  80.0      82       83      100
# VenusaurMega Venusaur        Grass  Poison  80.0     100      123      122
# Charizard                     Fire  Flying  78.0      84       78      109
# CharizardMega Charizard X     Fire  Dragon  78.0     130      111      130
# ...                            ...     ...   ...     ...      ...      ...
# Diancie                       Rock   Fairy  50.0     100      150      100
# DiancieMega Diancie           Rock   Fairy  50.0     160      110      160
# HoopaHoopa Confined        Psychic   Ghost  80.0     110       60      150
# HoopaHoopa Unbound         Psychic    Dark  80.0     160       60      170
# Volcanion                     Fire   Water  80.0     110      120      130
#
# ...

# %%
poke_csv
# Out:
#                           Name   Type 1  Type 2    HP  Attack  Defense  \
# #
# 2                      Ivysaur    Grass  Poison  60.0      62       63
# 3                     Venusaur    Grass  Poison  80.0      82       83
# 3        VenusaurMega Venusaur    Grass  Poison  80.0     100      123
# 6                    Charizard     Fire  Flying  78.0      84       78
# 6    CharizardMega Charizard X     Fire  Dragon  78.0     130      111
# ..                         ...      ...     ...   ...     ...      ...
# 719                    Diancie     Rock   Fairy  50.0     100      150
# 719        DiancieMega Diancie     Rock   Fairy  50.0     160      110
# 720        HoopaHoopa Confined  Psychic   Ghost  80.0     110       60
# 720         HoopaHoopa Unbound  Psychic    Dark  80.0     160       60
# 721                  Volcanion     Fire   Water  80.0     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# 2         80       80     60           1      False
# ...

# %%
#Gotcha: need to stat inplace=True for the method to work
poke_csv.set_index(['Name'], inplace=True)
poke_csv
# Out:
#                             Type 1  Type 2    HP  Attack  Defense  Sp. Atk  \
# Name
# Ivysaur                      Grass  Poison  60.0      62       63       80
# Venusaur                     Grass  Poison  80.0      82       83      100
# VenusaurMega Venusaur        Grass  Poison  80.0     100      123      122
# Charizard                     Fire  Flying  78.0      84       78      109
# CharizardMega Charizard X     Fire  Dragon  78.0     130      111      130
# ...                            ...     ...   ...     ...      ...      ...
# Diancie                       Rock   Fairy  50.0     100      150      100
# DiancieMega Diancie           Rock   Fairy  50.0     160      110      160
# HoopaHoopa Confined        Psychic   Ghost  80.0     110       60      150
# HoopaHoopa Unbound         Psychic    Dark  80.0     160       60      170
# Volcanion                     Fire   Water  80.0     110      120      130
#
# ...

# %% [markdown]
# # 3. Processing the data
# 1. What is the best pokemon? Sum all the points to give a maximum score.
# 2. Are legendary better the others?

# %%
#1 finding the ultimate pokeman
#not the fastest method but the easiest to understand

score = {}
for row, dseries in poke_csv.iterrows():
    score[row] = dseries[['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']].sum()

# %%
#making a dataframe out of a dictionary
score2 = pd.DataFrame.from_dict(score, orient='index', columns=['score'])
score2
# Out:
#                            score
# Ivysaur                    405.0
# Venusaur                   525.0
# VenusaurMega Venusaur      625.0
# Charizard                  534.0
# CharizardMega Charizard X  634.0
# ...                          ...
# Diancie                    600.0
# DiancieMega Diancie        700.0
# HoopaHoopa Confined        600.0
# HoopaHoopa Unbound         680.0
# Volcanion                  600.0
#
# [413 rows x 1 columns]

# %%
# add the score a s new column to poke_csv
poke_csv2 = pd.concat([poke_csv, score2], axis=1)
poke_csv2
# Out:
#                             Type 1  Type 2    HP  Attack  Defense  Sp. Atk  \
# Ivysaur                      Grass  Poison  60.0      62       63       80
# Venusaur                     Grass  Poison  80.0      82       83      100
# VenusaurMega Venusaur        Grass  Poison  80.0     100      123      122
# Charizard                     Fire  Flying  78.0      84       78      109
# CharizardMega Charizard X     Fire  Dragon  78.0     130      111      130
# ...                            ...     ...   ...     ...      ...      ...
# Diancie                       Rock   Fairy  50.0     100      150      100
# DiancieMega Diancie           Rock   Fairy  50.0     160      110      160
# HoopaHoopa Confined        Psychic   Ghost  80.0     110       60      150
# HoopaHoopa Unbound         Psychic    Dark  80.0     160       60      170
# Volcanion                     Fire   Water  80.0     110      120      130
#
# ...

# %%
poke_csv2.sort_values(['score'], ascending=False, inplace=True)
poke_csv2
# Out:
#                           Type 1    Type 2     HP  Attack  Defense  Sp. Atk  \
# MewtwoMega Mewtwo X      Psychic  Fighting  106.0     190      100      154
# RayquazaMega Rayquaza     Dragon    Flying  105.0     180      100      180
# GroudonPrimal Groudon     Ground      Fire  100.0     180      160      150
# GarchompMega Garchomp     Dragon    Ground  108.0     170      115      120
# MetagrossMega Metagross    Steel   Psychic   80.0     145      150      105
# ...                          ...       ...    ...     ...      ...      ...
# Wooper                     Water    Ground   55.0      45       45       25
# Kakuna                       Bug    Poison   45.0      25       50       25
# Ralts                    Psychic     Fairy   28.0      25       25       45
# Weedle                       Bug    Poison   40.0      35       30       20
# Azurill                   Normal     Fairy   50.0      20       40       20
#
# ...

# %%
# 4 Outputing the data

# %%
poke_csv2.to_excel('SortedByBestScore.xlsx')

# %%
plt.figure(figsize=(40,5))
poke_csv2['score'][:30].plot.bar()
plt.savefig('BestPOKE.svg')

# %% [markdown]
# # 3 Processing: Is legendary the best type?

# %%
legend = {}
for cgroup, cframe in poke_csv2.groupby(['Legendary']):
    print(cgroup)
    legend[cgroup] = cframe.mean()
# Out:
# False
# True

# %%
legend2 = pd.DataFrame.from_dict(data=legend)

# %%
legend2
# Out:
#                  False    True
# HP           67.954424   96.425
# Attack       79.294906  120.200
# Defense      77.624665   99.575
# Sp. Atk      71.823056  126.075
# Sp. Def      72.348525  105.825
# Speed        67.726542   97.150
# Generation    3.345845    4.075
# Legendary     0.000000    1.000
# score       436.772118  645.250

# %%
legend2.rename({True : 'Legendary', False: "Other"}, inplace=True, axis=1)
legend2.drop(['Legendary', 'Generation'], axis=0, inplace=True)
legend2
# Out:
#               Other  Legendary
# HP        67.954424     96.425
# Attack    79.294906    120.200
# Defense   77.624665     99.575
# Sp. Atk   71.823056    126.075
# Sp. Def   72.348525    105.825
# Speed     67.726542     97.150
# score    436.772118    645.250

# %%
legend2.plot.bar()
plt.savefig('Legendary.png')
